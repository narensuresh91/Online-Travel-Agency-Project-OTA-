# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('OTA-Project/OTA Project/train_small.csv')

# %%
data.describe()
# Out:
#           search_id       site_id  user_country_id  user_hist_stars  \
# count  2.380557e+06  2.380557e+06     2.380557e+06    122780.000000
# mean   3.337016e+05  9.970224e+00     1.754588e+02         3.382814
# std    1.923719e+05  7.667827e+00     6.585934e+01         0.694562
# min    4.000000e+00  1.000000e+00     1.000000e+00         1.500000
# 25%    1.674260e+05  5.000000e+00     1.000000e+02         2.950000
# 50%    3.332720e+05  5.000000e+00     2.190000e+02         3.450000
# 75%    5.007050e+05  1.400000e+01     2.190000e+02         3.950000
# max    6.655730e+05  3.400000e+01     2.310000e+02         5.000000
#
#        user_hist_paid  listing_country_id    listing_id  listing_stars  \
# count   123494.000000        2.380557e+06  2.380557e+06   2.380557e+06
# mean       178.094940        1.739159e+02  7.008190e+04   3.180607e+00
# std        108.568025        6.832483e+01  4.060398e+04   1.052086e+00
# ...

# %%
data.shape
# Out:
# (2380557, 54)

# %%
#Q1.a
data.dtypes
# Out:
# search_id                           int64
# timestamp                          object
# site_id                             int64
# user_country_id                     int64
# user_hist_stars                   float64
# user_hist_paid                    float64
# listing_country_id                  int64
# listing_id                          int64
# listing_stars                       int64
# listing_review_score              float64
# is_brand                            int64
# location_score1                   float64
# location_score2                   float64
# log_historical_price              float64
# listing_position                    int64
# price_usd                         float64
# has_promotion                       int64
# destination_id                      int64
# length_of_stay                      int64
# booking_window                      int64
# num_adults                          int64
# num_kids                            int64
# ...

# %%
data.head()
# Out:
#    search_id            timestamp  site_id  user_country_id  user_hist_stars  \
# 0          4  2012-12-31 08:59:22        5              219              NaN
# 1          4  2012-12-31 08:59:22        5              219              NaN
# 2          4  2012-12-31 08:59:22        5              219              NaN
# 3          4  2012-12-31 08:59:22        5              219              NaN
# 4          4  2012-12-31 08:59:22        5              219              NaN
#
#    user_hist_paid  listing_country_id  listing_id  listing_stars  \
# 0             NaN                 219        3625              4
# 1             NaN                 219       11622              4
# 2             NaN                 219       11826              5
# 3             NaN                 219       22824              3
# 4             NaN                 219       37581              5
#
#    listing_review_score  ...  competitor6_price_percent_diff  \
# ...

# %%
data['timestamp']=pd.to_datetime(data['timestamp'])

# %%
data
# Out:
#          search_id           timestamp  site_id  user_country_id  \
# 0                4 2012-12-31 08:59:22        5              219
# 1                4 2012-12-31 08:59:22        5              219
# 2                4 2012-12-31 08:59:22        5              219
# 3                4 2012-12-31 08:59:22        5              219
# 4                4 2012-12-31 08:59:22        5              219
# ...            ...                 ...      ...              ...
# 2380552     665573 2013-03-30 16:39:40        5              219
# 2380553     665573 2013-03-30 16:39:40        5              219
# 2380554     665573 2013-03-30 16:39:40        5              219
# 2380555     665573 2013-03-30 16:39:40        5              219
# 2380556     665573 2013-03-30 16:39:40        5              219
#
#          user_hist_stars  user_hist_paid  listing_country_id  listing_id  \
# 0                    NaN             NaN                 219        3625
# ...

# %%
#Q1.b
data.isnull().sum()
# Out:
# search_id                               0
# timestamp                               0
# site_id                                 0
# user_country_id                         0
# user_hist_stars                   2257777
# user_hist_paid                    2257063
# listing_country_id                      0
# listing_id                              0
# listing_stars                           0
# listing_review_score                 3486
# is_brand                                0
# location_score1                         0
# location_score2                    525992
# log_historical_price                    0
# listing_position                        0
# price_usd                               0
# has_promotion                           0
# destination_id                          0
# length_of_stay                          0
# booking_window                          0
# num_adults                              0
# num_kids                                0
# ...

# %%
data.describe()
# Out:
#           search_id       site_id  user_country_id  user_hist_stars  \
# count  2.380557e+06  2.380557e+06     2.380557e+06    122780.000000
# mean   3.337016e+05  9.970224e+00     1.754588e+02         3.382814
# std    1.923719e+05  7.667827e+00     6.585934e+01         0.694562
# min    4.000000e+00  1.000000e+00     1.000000e+00         1.500000
# 25%    1.674260e+05  5.000000e+00     1.000000e+02         2.950000
# 50%    3.332720e+05  5.000000e+00     2.190000e+02         3.450000
# 75%    5.007050e+05  1.400000e+01     2.190000e+02         3.950000
# max    6.655730e+05  3.400000e+01     2.310000e+02         5.000000
#
#        user_hist_paid  listing_country_id    listing_id  listing_stars  \
# count   123494.000000        2.380557e+06  2.380557e+06   2.380557e+06
# mean       178.094940        1.739159e+02  7.008190e+04   3.180607e+00
# std        108.568025        6.832483e+01  4.060398e+04   1.052086e+00
# ...

# %%
#Q1.c
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True)

# %%
data['user_hist_stars'].unique()
# Out:
# array([ nan, 2.5 , 5.  , 2.3 , 3.  , 3.17, 2.9 , 3.67, 2.94, 2.6 , 4.  ,
#        3.51, 3.5 , 3.24, 4.25, 3.35, 2.67, 2.  , 3.91, 2.83, 3.06, 3.8 ,
#        2.62, 3.1 , 3.72, 4.11, 3.12, 4.31, 4.5 , 4.46, 3.38, 4.33, 3.66,
#        3.56, 3.33, 3.97, 4.02, 4.18, 3.86, 3.9 , 3.7 , 3.4 , 3.53, 3.68,
#        3.46, 4.1 , 2.42, 2.25, 4.08, 3.71, 3.08, 2.79, 4.12, 2.61, 2.93,
#        3.99, 3.13, 3.79, 3.78, 3.75, 2.72, 3.29, 3.61, 2.87, 4.23, 3.95,
#        4.35, 2.7 , 3.18, 4.56, 2.46, 3.94, 2.41, 3.89, 3.42, 3.55, 2.78,
#        2.22, 2.53, 3.74, 3.88, 3.62, 3.3 , 3.31, 2.35, 2.2 , 3.28, 4.65,
#        3.25, 3.77, 3.45, 3.41, 2.33, 4.28, 2.29, 4.4 , 3.21, 2.8 , 3.01,
#        3.16, 2.64, 3.05, 2.14, 3.83, 4.21, 2.07, 3.84, 3.54, 4.72, 3.43,
#        3.39, 2.86, 4.6 , 3.98, 2.48, 3.07, 2.06, 4.04, 2.19, 2.03, 1.83,
#        2.39, 3.73, 2.74, 4.2 , 3.58, 3.57, 4.57, 4.06, 3.93, 2.21, 3.2 ,
#        2.04, 2.75, 4.07, 2.13, 3.76, 2.92, 3.36, 2.77, 3.22, 3.82, 3.69,
# ...

# %%
data['user_hist_stars'].replace(np.nan,0,inplace=True)

# %%
data['user_hist_paid'].unique()
# Out:
# array([   nan, 122.34, 185.91, ..., 265.73, 241.16, 242.69])

# %%
#Q1.d
#There are a lot of null values in the dataset. These are due to the no data available for the customer, but for the purpose of machine learning,this will have to be replaced with the meanv/vmedian to perform the model, however this could result in a biased model

# %%
data['user_hist_paid'].replace(np.nan,0,inplace=True)

# %%
data['listing_review_score'].unique()
# Out:
# array([4. , 4.5, 3. , 3.5, 2. , 2.5, 0. , 5. , 1. , 1.5, nan])

# %%
data['listing_review_score'].replace(np.nan,data['listing_review_score'].mean(),inplace=True)

# %%
data['location_score2'].replace(np.nan,data['location_score2'].mean(),inplace=True)

# %%
data['log_click_proportion'].replace(np.nan,0,inplace=True)

# %%
data['distance_to_dest'].replace(np.nan,data['distance_to_dest'].mean(),inplace=True)

# %%
data['competitor1_rate'].value_counts()
# Out:
#  1.0    33366
#  0.0    20847
# -1.0     4797
# Name: competitor1_rate, dtype: int64

# %%
data['competitor1_rate'].replace(np.nan,0,inplace=True)
data['competitor1_has_availability'].replace(np.nan,0,inplace=True)
data['competitor1_price_percent_diff'].replace(np.nan,0,inplace=True)
data['competitor2_rate'].replace(np.nan,0,inplace=True)
data['competitor2_has_availability'].replace(np.nan,0,inplace=True)
data['competitor2_price_percent_diff'].replace(np.nan,0,inplace=True)
data['competitor3_rate'].replace(np.nan,0,inplace=True)
data['competitor3_has_availability'].replace(np.nan,0,inplace=True)
data['competitor3_price_percent_diff'].replace(np.nan,0,inplace=True)
data['competitor4_rate'].replace(np.nan,0,inplace=True)
data['competitor4_has_availability'].replace(np.nan,0,inplace=True)
data['competitor4_price_percent_diff'].replace(np.nan,0,inplace=True)
data['competitor5_rate'].replace(np.nan,0,inplace=True)
data['competitor5_has_availability'].replace(np.nan,0,inplace=True)
data['competitor5_price_percent_diff'].replace(np.nan,0,inplace=True)
data['competitor6_rate'].replace(np.nan,0,inplace=True)
data['competitor6_has_availability'].replace(np.nan,0,inplace=True)
data['competitor6_price_percent_diff'].replace(np.nan,0,inplace=True)
data['competitor7_rate'].replace(np.nan,0,inplace=True)
data['competitor7_has_availability'].replace(np.nan,0,inplace=True)
data['competitor7_price_percent_diff'].replace(np.nan,0,inplace=True)
data['competitor8_rate'].replace(np.nan,0,inplace=True)
data['competitor8_has_availability'].replace(np.nan,0,inplace=True)
data['competitor8_price_percent_diff'].replace(np.nan,0,inplace=True)

# %%
data['booking_value'].value_counts()
# Out:
# 133.69    25
# 89.99     24
# 143.87    18
# 208.90    18
# 231.85    18
#           ..
# 241.60     1
# 241.40     1
# 384.79     1
# 85.82      1
# 346.68     1
# Name: booking_value, Length: 39587, dtype: int64

# %%
data['booking_value'].replace(np.nan,0,inplace=True)

# %%
data.isnull().sum()
# Out:
# search_id                         0
# timestamp                         0
# site_id                           0
# user_country_id                   0
# user_hist_stars                   0
# user_hist_paid                    0
# listing_country_id                0
# listing_id                        0
# listing_stars                     0
# listing_review_score              0
# is_brand                          0
# location_score1                   0
# location_score2                   0
# log_historical_price              0
# listing_position                  0
# price_usd                         0
# has_promotion                     0
# destination_id                    0
# length_of_stay                    0
# booking_window                    0
# num_adults                        0
# num_kids                          0
# num_rooms                         0
# stay_on_saturday                  0
# log_click_proportion              0
# distance_to_dest                  0
# ...

# %%
#Q1.e There are multiple blanks in the dataset. The best practice to address the issues is to find the actual values and populating the dataset.
#For the purpose of the project some data management techniques have been used.

# %%
#Q1.f Data privacy issues are non existent in the dataset. There are data which are confidential,but however since the given information is not enough to track down and customer or a competitior, there should not be a problem

# %%
#Q2.a Click through rate
ctr=(data['clicked'].sum()/data['listing_position'].sum())*100
ctr
# Out:
# 0.26421543885914434

# %%
#Q2.a conversion rate
cr=(data['booked'].sum()/data['clicked'].sum())*100
cr
# Out:
# 62.5746979094011

# %%
#Q2.b

# %%
data['search_id'].value_counts()
# Out:
# 223395    38
# 597375    38
# 394061    38
# 427467    37
# 353559    37
#           ..
# 504960     5
# 565106     5
# 648733     5
# 156360     5
# 137503     5
# Name: search_id, Length: 95842, dtype: int64

# %%
data.drop(['timestamp'],axis=1,inplace=True)

# %%
collist=data.columns.values
ncol=17
nrow=12
plt.figure(figsize=(2*ncol,4*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data[collist[i]],color='blue',orient='v')

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
print(x.shape)
print(y.shape)
# Out:
# (2380557, 52)
# (2380557,)

# %%
y
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 2380552    0
# 2380553    0
# 2380554    0
# 2380555    0
# 2380556    0
# Name: booked, Length: 2380557, dtype: int64

# %%
y=y.values.reshape(-1,1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x.shape
# Out:
# (2380557, 52)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,auc,roc_curve

# %%
lr=LogisticRegression()
gnb=GaussianNB()
knc=KNeighborsClassifier(n_neighbors=8)
svc=SVC()
dtc=DecisionTreeClassifier(random_state=6)
rfc=RandomForestClassifier(n_estimators=200,random_state=42)

# %%
models =[]
models.append(('LogisticRegression',lr))
models.append(('GaussianNB',gnb))
models.append(('DecisionTreeClassifier',dtc))

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for name,model in models:
    print('**************',name,'***********')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pred)
    score.append(AS*100)
    print('Accuracy Score =',AS)
    print('\n')
    cm=confusion_matrix(y_test,pred)
    print('Confusion Matrix =',cm)
    clr=classification_report(y_test,pred)
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross Val Score =',sc)
    cvs.append(sc*100)
# Out:
# ************** LogisticRegression ***********
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# Accuracy Score = 0.9999445508619821
#
#
# Confusion Matrix = [[578543      0]
#  [    33  16564]]
# Cross Val Score = 0.9999508518351033
# ************** GaussianNB ***********
#
#
# GaussianNB(priors=None, var_smoothing=1e-09)
#
#
# Accuracy Score = 0.9833282925026045
#
#
# Confusion Matrix = [[568621   9922]
#  [     0  16597]]
# Cross Val Score = 0.9834421105099013
# ************** DecisionTreeClassifier ***********
#
#
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
# ...

# %%
#3b.
#1. booked (yes/ no) was considered as the target variable. It was chosen because it had no blanks and no assumptions had to be made to get the final results of those unlike the booking_value
#2. No features were dropped, all features were included in the creation of the model.
#3. Initially, the blanks were treated using certain data handling techniques. Later the standard scaler was applied to the features. If the blanks or nans were not handled, getting the model would have been impossible. If the standard scaler was not applied, the data would have been skewed.
#4. Logistic regression was used as the base model along with Gaussian NB and decision trees. The aim of the model was to predict if the rooms were booked / not which required a two channel output system
#5.Accuracy and confusion matrix were chosen as the metrics. Also for validation, cross_validation score was calculated.
#6.Considering the accuracy score alone could not give a complete picture of the model. The model could have a high accuracy score and still be biased.
#7.The model is fairly simple enough.
